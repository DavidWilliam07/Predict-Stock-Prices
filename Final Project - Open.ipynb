# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %% [markdown]
# # Mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Import Data

# %% [markdown]
# ## Data Training

# %%
trainData = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FGA/Final Project/Data_training.csv')
trainData.head()
# Out:
#          Date   Open   High    Low  Close   Adj Close     Volume
# 0  2005-01-03  295.0  295.0  292.5  295.0  198.727997  126180000
# 1  2005-01-04  295.0  302.5  295.0  300.0  202.096313  291730000
# 2  2005-01-05  300.0  315.0  300.0  307.5  207.148727  564730000
# 3  2005-01-06  310.0  310.0  302.5  307.5  207.148727  161150000
# 4  2005-01-07  305.0  305.0  292.5  295.0  198.727997  592910000

# %%
trainData.tail()
# Out:
#             Date    Open    High     Low   Close    Adj Close    Volume
# 3721  2019-12-20  6680.0  6740.0  6610.0  6660.0  6002.917969  99453000
# 3722  2019-12-23  6680.0  6730.0  6650.0  6660.0  6002.917969  46558500
# 3723  2019-12-26  6660.0  6725.0  6660.0  6680.0  6020.944824  38188500
# 3724  2019-12-27  6670.0  6700.0  6670.0  6695.0  6034.464844  29945000
# 3725  2019-12-30  6680.0  6720.0  6670.0  6685.0  6025.451172  61168000

# %% [markdown]
# ## Data Testing

# %%
testData = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/FGA/Final Project/Data_testing.csv')
testData.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close    Volume
# 0  2020-01-02  6695.0  6780.0  6680.0  6690.0  6029.958008  49445000
# 1  2020-01-03  6750.0  6800.0  6725.0  6800.0  6129.104980  47755500
# 2  2020-01-06  6720.0  6750.0  6690.0  6735.0  6070.518066  27300000
# 3  2020-01-07  6735.0  6770.0  6730.0  6740.0  6075.024902  45022500
# 4  2020-01-08  6670.0  6745.0  6670.0  6680.0  6020.944336  53692500

# %%
testData.tail()
# Out:
#            Date    Open    High     Low   Close    Adj Close    Volume
# 969  2023-12-21  9300.0  9325.0  9250.0  9325.0  9114.956055  88116700
# 970  2023-12-22  9275.0  9350.0  9275.0  9325.0  9114.956055  64449600
# 971  2023-12-27  9375.0  9400.0  9325.0  9375.0  9163.830078  64464700
# 972  2023-12-28  9325.0  9425.0  9325.0  9400.0  9188.267578  70184600
# 973  2023-12-29  9425.0  9450.0  9350.0  9400.0  9188.267578  79903400

# %% [markdown]
# # 2. Pre-processing data

# %% [markdown]
# ## Data Training

# %%
trainData["Date"] = pd.to_datetime(trainData['Date'])
trainData["Open"] = pd.to_numeric(trainData.Open,errors='coerce')

# %%
trainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3726 entries, 0 to 3725
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3726 non-null   datetime64[ns]
#  1   Open       3726 non-null   float64
#  2   High       3726 non-null   float64
#  3   Low        3726 non-null   float64
#  4   Close      3726 non-null   float64
#  5   Adj Close  3726 non-null   float64
#  6   Volume     3726 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 203.9 KB

# %%
print(f"Dataframe data training contains stick prices between {trainData.Date.min()} {trainData.Date.max()}")
# Out:
# Dataframe data training contains stick prices between 2005-01-03 00:00:00 2019-12-30 00:00:00

# %%
trainData.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           3726  3726.000000  3726.000000  3726.000000
# mean   2012-07-15 12:12:45.217391360  2088.468867  2108.306495  2067.744230
# min              2005-01-03 00:00:00   277.500000   282.500000   272.500000
# 25%              2008-09-25 06:00:00   640.000000   650.000000   630.000000
# 50%              2012-07-14 12:00:00  1610.000000  1620.000000  1590.000000
# 75%              2016-05-10 18:00:00  2827.500000  2860.000000  2805.000000
# max              2019-12-30 00:00:00  6700.000000  6800.000000  6670.000000
# std                              NaN  1621.527724  1631.897144  1611.147313
#
#              Close    Adj Close        Volume
# count  3726.000000  3726.000000  3.726000e+03
# mean   2089.015030  1784.183621  1.053028e+08
# min     277.500000   186.939072  0.000000e+00
# 25%     640.000000   487.824097  4.549275e+07
# 50%    1610.000000  1320.191284  7.012875e+07
# 75%    2825.000000  2418.145996  1.163700e+08
# max    6755.000000  6088.545410  1.949960e+09
# std    1621.921087  1473.475242  1.267092e+08

# %%
trainData.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
trainData = trainData.iloc[:,1:2].values
trainData
# Out:
# array([[ 295.],
#        [ 295.],
#        [ 300.],
#        ...,
#        [6660.],
#        [6670.],
#        [6680.]])

# %%
trainData.shape
# Out:
# (3726, 1)

# %% [markdown]
# ## Data Testing

# %%
testData["Date"] = pd.to_datetime(testData['Date'])
testData["Open"] = pd.to_numeric(testData.Open,errors='coerce')

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       974 non-null    datetime64[ns]
#  1   Open       974 non-null    float64
#  2   High       974 non-null    float64
#  3   Low        974 non-null    float64
#  4   Close      974 non-null    float64
#  5   Adj Close  974 non-null    float64
#  6   Volume     974 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 53.4 KB

# %%
print(f"Dataframe data testing contains stick prices between {testData.Date.min()} {testData.Date.max()}")
# Out:
# Dataframe data testing contains stick prices between 2020-01-02 00:00:00 2023-12-29 00:00:00

# %%
testData.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                            974   974.000000   974.000000   974.000000
# mean   2021-12-30 22:16:30.554414592  7412.381930  7481.822382  7341.611910
# min              2020-01-02 00:00:00  4450.000000  4800.000000  4325.000000
# 25%              2021-01-05 06:00:00  6420.000000  6471.250000  6351.250000
# 50%              2021-12-28 12:00:00  7400.000000  7475.000000  7325.000000
# 75%              2022-12-25 06:00:00  8600.000000  8693.750000  8550.000000
# max              2023-12-29 00:00:00  9425.000000  9450.000000  9375.000000
# std                              NaN  1208.296995  1205.169403  1219.812893
#
#              Close    Adj Close        Volume
# count   974.000000   974.000000  9.740000e+02
# mean   7410.595483  6983.687871  8.973214e+07
# min    4430.000000  3992.931396  0.000000e+00
# 25%    6410.000000  5924.133301  5.821892e+07
# 50%    7375.000000  6947.797852  7.705595e+07
# 75%    8600.000000  8202.416992  1.057043e+08
# max    9400.000000  9188.267578  7.228279e+08
# std    1214.980092  1289.998164  5.727483e+07

# %%
testData.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
testData = testData.iloc[:,4:5]
y_test = testData.iloc[20:, 0:].values

# %%
y_test.shape
# Out:
# (954, 1)

# %% [markdown]
# # 3. Feature Scaling

# %% [markdown]
# ## Data Training

# %%
sc = MinMaxScaler(feature_range=(0,1))
trainData = sc.fit_transform(trainData)
trainData.shape
# Out:
# (3726, 1)

# %% [markdown]
# ## Data Testing

# %%
inputOpen = testData.iloc[:,0:].values
inputOpen_scaled = sc.fit_transform(inputOpen)
inputOpen_scaled.shape
# Out:
# (974, 1)

# %% [markdown]
# # 4. Training Data

# %% [markdown]
# ## Splitting Data

# %%
X_train = []
y_train = []

for i in range (20, len(trainData)): # 60 = timestep
    X_train.append(trainData[i-20:i,0])
    y_train.append(trainData[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1)) #adding the batch_size axis

# %%
print("X train shape : ", X_train.shape)
print("y train shape : ", y_train.shape)
# Out:
# X train shape :  (3706, 20, 1)
# y train shape :  (3706,)

# %%
X_test = []
length = len(testData)
timestep = 20

for i in range(timestep,length):
    X_test.append(inputOpen_scaled[i-timestep:i,0])

X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
print("X test shape : ", X_test.shape)
print("y test shape : ", y_test.shape)
# Out:
# X test shape :  (954, 20, 1)
# y test shape :  (954, 1)

# %% [markdown]
# ## Build LSTM Model

# %%
model = Sequential()

model.add(LSTM(units=200, return_sequences = True, input_shape = (X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "relu", return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "relu",return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "linear", return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units = 1))
model.compile(optimizer='adam', loss = "mean_squared_error")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 20, 200)             │         161,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20, 200)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 20, 200)             │         320,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 20, 200)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 20, 200)             │         320,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 20, 200)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 200)                 │         320,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             201 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,124,201 (4.29 MB)
#  Trainable params: 1,124,201 (4.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Visualisasi Model

# %%
tf.keras.utils.plot_model(model,
                          show_shapes = True,
                          show_dtype = False,
                          show_layer_names = True,
                          expand_nested = True,
                          show_layer_activations = True)

# %% [markdown]
# # Fit Model

# %%
hist = model.fit(X_train, y_train,
                 epochs = 10,
                 batch_size = 64,
                 verbose = 1,
                 validation_data = (X_train, y_train))
# Out:
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 39s 416ms/step - loss: 0.0395 - val_loss: 5.4415e-04
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 26s 443ms/step - loss: 8.0506e-04 - val_loss: 3.3863e-04
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 47s 543ms/step - loss: 7.4060e-04 - val_loss: 4.2974e-04
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 34s 426ms/step - loss: 7.0666e-04 - val_loss: 2.5185e-04
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 42s 447ms/step - loss: 6.6808e-04 - val_loss: 1.8487e-04
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 41s 448ms/step - loss: 5.3139e-04 - val_loss: 1.9103e-04
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 43s 484ms/step - loss: 6.3004e-04 - val_loss: 5.4275e-04
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 37s 408ms/step - loss: 6.3393e-04 - val_loss: 1.6634e-04
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 41s 407ms/step - loss: 6.5791e-04 - val_loss: 2.3580e-04
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 41s 410ms/step - loss: 5.6183e-04 - val_loss: 2.0536e-04

# %% [markdown]
# ## Evaluation Model

# %%
model.metrics_names
# Out:
# ['loss']

# %%
score_training = model.evaluate(X_train, y_train, verbose = 1)
print('Training loss :', score_training)
# Out:
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - loss: 7.4944e-05
# Training loss : 0.00020535582734737545

# %% [markdown]
# ## Visualisasi Training Model Loss

# %%
plt.plot(hist.history['loss'])
plt.title('Training model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ## Save Model LSTM

# %%
model.save("saved_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # 5. Prediction Data

# %%
X_pred = model.predict(X_train)
X_pred.shape
# Out:
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step
# (3706, 1)

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step
# (954, 1)

# %% [markdown]
# ## Feature Scaling

# %%
X_pred = sc.inverse_transform(X_pred)

# %%
predicted_price = sc.inverse_transform(y_pred)

# %% [markdown]
# # Visualisasi hasil prediksi dengan harga aktual

# %%
difference = predicted_price - y_test

# %%
print(y_test.shape)
print(predicted_price.shape)
print(difference.shape)
# Out:
# (954, 1)
# (954, 1)
# (954, 1)

# %%
Prediction = pd.DataFrame ({"nilai aktual" : y_test.flatten(),
                            "nilai prediksi " : predicted_price.flatten(),
                            "Difference " : difference.flatten()})
Prediction
# Out:
#      nilai aktual  nilai prediksi   Difference
# 0          6740.0      6869.398438   129.398438
# 1          6480.0      6877.763184   397.763184
# 2          6440.0      6880.304688   440.304688
# 3          6600.0      6882.460938   282.460938
# 4          6730.0      6880.930176   150.930176
# ..            ...              ...          ...
# 949        9325.0      8987.720703  -337.279297
# 950        9325.0      8994.781250  -330.218750
# 951        9375.0      9007.313477  -367.686523
# 952        9400.0      9026.919922  -373.080078
# 953        9400.0      9051.421875  -348.578125
#
# [954 rows x 3 columns]

# %%
plt.plot(difference, color = "blue", label = "Difference")
plt.title('BCA stock price prediction difference')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.legend()
plt.show()

# %%
plt.plot(y_test, color = 'red', label = 'Actual Stock Price')
plt.plot(predicted_price, color = 'green', label = 'Predicted Stock Price')
plt.title('BCA stock price prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 6. Result and Conclusion

# %% [markdown]
# ## RMSE ( Root Mean Squared Error )

# %%
import math
from sklearn.metrics import mean_squared_error

print("Train RMSE : ", math.sqrt(mean_squared_error(y_train, X_pred)))
print("Test RMSE : ", math.sqrt(mean_squared_error(y_test, predicted_price)))
# Out:
# Train RMSE :  6000.956495803135
# Test RMSE :  300.5317324595878

# %% [markdown]
# ## MSE ( Mean Squared Error )

# %%
# MSE Training
MSE_train = np.square(np.subtract(y_train, X_pred)).mean()
print("Train MSE : ", MSE_train)

# MSE Testing
MSE_test = np.square(np.subtract(y_test, predicted_price)).mean()
print("Testing MSE : ", MSE_test)
# Out:
# Train MSE :  36012120.76492488
# Testing MSE :  90319.32221516123

# %% [markdown]
# ## MAE ( Mean Absolute Error )

# %%
from sklearn.metrics import mean_absolute_error as mae

# MAE Training
mae_train = mae(y_train, X_pred)
print("MAE Training : " + str(mae_train))

# MAE Testing
mae_test = mae(y_test, predicted_price)
print("MAE Testing : " + str(mae_test))
# Out:
# MAE Training : 5864.261259857487
# MAE Testing : 226.32607462821016

# %% [markdown]
# **Catatan** : Dengan nilai error yang tinggi menunjukkan bahwa pergerakan harga saham saat covid yaitu mulai dari Januari 2020 tidak dapat diprediksi menggunakan data historis sebelumnya karena merupakan sebuah anomali dimana pergerakan harga saham saat covid menjadi sangat tidak menentu
